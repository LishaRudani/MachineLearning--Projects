# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Teach_Foundation_of_ML/project/Regression/archive.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Teach_Foundation_of_ML/project/Regression/archive.zip, /content/drive/MyDrive/Teach_Foundation_of_ML/project/Regression/archive.zip.zip or /content/drive/MyDrive/Teach_Foundation_of_ML/project/Regression/archive.zip.ZIP.

# %%
data= pd.read_csv('/content/drive/MyDrive/shooting_Dataset/shootings_2022.csv')

# %%
data
# Out:
#           Date       State  Dead  Injured  Total  \
# 0   03-03-2022      Nevada     1        6      7
# 1   02-03-2022    Maryland     1        3      4
# 2   28-02-2022  California     5        0      5
# 3   27-02-2022  California     0        4      4
# 4   27-02-2022   Louisiana     0        4      4
# ..         ...         ...   ...      ...    ...
# 76  01-01-2022     Georgia     1        3      4
# 77  01-01-2022   Wisconsin     1        3      4
# 78  01-01-2022     Indiana     0        4      4
# 79  01-01-2022    Colorado     2        2      4
# 80  01-01-2022    Missouri     0        4      4
#
#                                           Description
# 0   A dispute between neighbors led to a shooting ...
# 1   Four men were shot in the Walbrook neighborhoo...
# 2   A man fatally shot himself, his three children...
# 3   An argument between two groups of people at a ...
# 4   An argument at a business in the southeast par...
# ...

# %%
data.shape
# Out:
# (81, 6)

# %%
data.head()
# Out:
#          Date       State  Dead  Injured  Total  \
# 0  03-03-2022      Nevada     1        6      7
# 1  02-03-2022    Maryland     1        3      4
# 2  28-02-2022  California     5        0      5
# 3  27-02-2022  California     0        4      4
# 4  27-02-2022   Louisiana     0        4      4
#
#                                          Description
# 0  A dispute between neighbors led to a shooting ...
# 1  Four men were shot in the Walbrook neighborhoo...
# 2  A man fatally shot himself, his three children...
# 3  An argument between two groups of people at a ...
# 4  An argument at a business in the southeast par...

# %%
data.tail()
# Out:
#           Date      State  Dead  Injured  Total  \
# 76  01-01-2022    Georgia     1        3      4
# 77  01-01-2022  Wisconsin     1        3      4
# 78  01-01-2022    Indiana     0        4      4
# 79  01-01-2022   Colorado     2        2      4
# 80  01-01-2022   Missouri     0        4      4
#
#                                           Description
# 76  After officers were dispatched to respond to a...
# 77  A man was killed and three others wounded in a...
# 78  Four people were wounded at a New Years party ...
# 79  Two adults were killed and two wounded in an e...
# 80  Four adults were wounded in the early morning ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         81 non-null     object
#  1   State        81 non-null     object
#  2   Dead         81 non-null     int64
#  3   Injured      81 non-null     int64
#  4   Total        81 non-null     int64
#  5   Description  81 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 3.9+ KB

# %%
data.describe()
# Out:
#             Dead    Injured      Total
# count  81.000000  81.000000  81.000000
# mean    1.135802   3.802469   4.938272
# std     1.339338   2.288120   2.063648
# min     0.000000   0.000000   4.000000
# 25%     0.000000   3.000000   4.000000
# 50%     1.000000   4.000000   4.000000
# 75%     1.000000   4.000000   5.000000
# max     6.000000  14.000000  16.000000

# %%
data.isnull().sum()
# Out:
# Date           0
# State          0
# Dead           0
# Injured        0
# Total          0
# Description    0
# dtype: int64

# %%
total_victims_state = data.groupby('State').sum()
print('Total Victims = ' ,total_victims_state['Total'].sum())
total_victims_state.sort_values(by = 'Total', ascending = False)
# Out:
# Total Victims =  400
#                  Dead  Injured  Total
# State
# California         15       38     53
# Texas              15       22     37
# Georgia             9       25     34
# Missouri            5       23     28
# Louisiana           2       20     22
# Wisconsin           8       13     21
# Nevada              2       19     21
# Florida             3       15     18
# Illinois            3       15     18
# Oregon              2       14     16
# Tennessee           5        8     13
# North Carolina      2       10     12
# Arizona             2        9     11
# Alabama             1       10     11
# Mississippi         2        7      9
# Pennsylvania        1        8      9
# South Carolina      1        8      9
# New Mexico          1        7      8
# Maryland            4        4      8
# Colorado            4        4      8
# Virginia            1        4      5
# Washington D.C.     1        4      5
# Minnesota           1        3      4
# ...

# %%
total_victims_state.sort_values(by = 'Total', ascending = False).head()
# Out:
#             Dead  Injured  Total
# State
# California    15       38     53
# Texas         15       22     37
# Georgia        9       25     34
# Missouri       5       23     28
# Louisiana      2       20     22

# %%
total_victims_state.sort_values(by = 'Total', ascending = False).tail()
# Out:
#             Dead  Injured  Total
# State
# New York       0        4      4
# Indiana        0        4      4
# Arkansas       1        3      4
# Washington     1        3      4
# Nebraska       0        4      4

# %%
plt.subplots(figsize = (15, 6))
cr = total_victims_state['Total'].sort_values(ascending = False)
ax = cr.plot.bar()
ax.set_xlabel('State')
ax.set_ylabel('Total Number = Dead + Enjured')
ax.set_title('Statewise total Reported cases')
plt.show()
print(cr)
# Out:
# State
# California         53
# Texas              37
# Georgia            34
# Missouri           28
# Louisiana          22
# Wisconsin          21
# Nevada             21
# Florida            18
# Illinois           18
# Oregon             16
# Tennessee          13
# North Carolina     12
# Arizona            11
# Alabama            11
# Mississippi         9
# Pennsylvania        9
# South Carolina      9
# New Mexico          8
# Maryland            8
# Colorado            8
# Virginia            5
# Washington D.C.     5
# Minnesota           4
# New York            4
# Indiana             4
# Arkansas            4
# Washington          4
# Nebraska            4
# Name: Total, dtype: int64

# %%
california_victims = data[data['State'] == 'California']

# %%
california_victims.head()
# Out:
#           Date       State  Dead  Injured  Total  \
# 2   28-02-2022  California     5        0      5
# 3   27-02-2022  California     0        4      4
# 21  19-02-2022  California     0        7      7
# 28  12-02-2022  California     0        4      4
# 33  06-02-2022  California     2        2      4
#
#                                           Description
# 2   A man fatally shot himself, his three children...
# 3   An argument between two groups of people at a ...
# 21  A man shot seven people outside a bar in the e...
# 28  Outside an Italian restaurant hosting a party ...
# 33  A chance encounter between two rival gangs at ...

# %%
pip install squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import squarify
y = data['Total'].value_counts().head(25)
plt.rcParams['figure.figsize'] = (15, 15)
plt.style.use('fivethirtyeight')
color = plt.cm.magma(np.linspace(0, 1, 15))
squarify.plot(sizes = y.values, label = y.index, alpha=.8, color = color, pad = True)
plt.title('Tree Map for Top Crime', fontsize = 20)
plt.axis('off')
plt.show()

# %%
plt.style.use('seaborn')
data['Date'].value_counts().head(15).plot.pie(figsize = (15, 8))
plt.title('Crime count on each day',fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Month'] = data['Date'].dt.month
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15, 8)
sns.countplot(data['Month'], palette = 'autumn',)
plt.title('Crimes in each Months', fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(20,6))
ax = sns.boxplot(x='State',y='Total',data=data)
plt.xticks(rotation=90)
ax.set_title("Crime Distribution")
# Out:
# Text(0.5, 1.0, 'Crime Distribution')

# %%
plt.figure(figsize=(24,12))
sns.scatterplot(x="Total",y="State",data=data)

# %%
data.head()
# Out:
#         Date       State  Dead  Injured  Total  \
# 0 2022-03-03      Nevada     1        6      7
# 1 2022-02-03    Maryland     1        3      4
# 2 2022-02-28  California     5        0      5
# 3 2022-02-27  California     0        4      4
# 4 2022-02-27   Louisiana     0        4      4
#
#                                          Description  Month
# 0  A dispute between neighbors led to a shooting ...      3
# 1  Four men were shot in the Walbrook neighborhoo...      2
# 2  A man fatally shot himself, his three children...      2
# 3  An argument between two groups of people at a ...      2
# 4  An argument at a business in the southeast par...      2

# %%
x = data.drop(['Date', 'State', 'Description'], axis = 1)
y = data['Total']

# %%
x.shape
# Out:
# (81, 4)

# %%
y.shape
# Out:
# (81,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Training Accuracy :", model.score(X_train, y_train))
print("Testing Accuracy :", model.score(X_test, y_test))
# Out:
# Training Accuracy : 0.921875
# Testing Accuracy : 0.7647058823529411

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model1= LinearRegression()
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model1.predict(X_test)

# %%
print("Training Accuracy :", model1.score(X_train, y_train))
print("Testing Accuracy :", model1.score(X_test, y_test))
# Out:
# Training Accuracy : 1.0
# Testing Accuracy : 1.0
